# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = "Model/Dataset"
data_test_path = "Model/test"
data_val_path = "Model/validation"

# %%
img_width = 180
img_height = 180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size =(img_width,img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 207 files belonging to 3 classes.

# %%
data_cat =data_train.class_names

# %%
data_cat
# Out:
# ['Fire', 'Flood', 'earthquake']

# %%
data_val= tf.keras.utils.image_dataset_from_directory(
    data_val_path,
    shuffle=False,
    image_size =(img_width,img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 24 files belonging to 3 classes.

# %%
data_test= tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle=False,
    image_size =(img_width,img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 27 files belonging to 3 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype("uint8"))
        plt.title(data_cat[labels[i]])
        plt.axis("off")

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16,3,padding="same",activation="relu"),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3,padding="same",activation="relu"),
    layers.MaxPool2D(),
    layers.Conv2D(64,3,padding="same",activation="relu"),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
])

# %%
model.compile(optimizer="adam",loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=["accuracy"])

# %%
epochs_size =25
history = model.fit(data_train,validation_data=data_val , epochs=epochs)
# Out:
# Epoch 1/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.3991 - loss: 3.4533 - val_accuracy: 0.0370 - val_loss: 1.6709
# Epoch 2/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 993ms/step - accuracy: 0.5259 - loss: 1.1969 - val_accuracy: 0.0370 - val_loss: 1.8425
# Epoch 3/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 630ms/step - accuracy: 0.5697 - loss: 0.8059 - val_accuracy: 0.0370 - val_loss: 3.0483
# Epoch 4/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 680ms/step - accuracy: 0.7998 - loss: 0.5280 - val_accuracy: 0.1111 - val_loss: 4.7014
# Epoch 5/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 628ms/step - accuracy: 0.8147 - loss: 0.5228 - val_accuracy: 0.0741 - val_loss: 4.4359
# Epoch 6/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 468ms/step - accuracy: 0.8592 - loss: 0.3123 - val_accuracy: 0.0000e+00 - val_loss: 5.5037
# Epoch 7/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 974ms/step - accuracy: 0.8873 - loss: 0.2974 - val_accuracy: 0.0741 - val_loss: 6.0379
# Epoch 8/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9509 - loss: 0.1929 - val_accuracy: 0.1481 - val_loss: 7.5928
# Epoch 9/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9480 - loss: 0.1395 - val_accuracy: 0.1852 - val_loss: 7.6399
# Epoch 10/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.9883 - loss: 0.0801 - val_accuracy: 0.0000e+00 - val_loss: 7.4494
# Epoch 11/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 954ms/step - accuracy: 0.9874 - loss: 0.0874 - val_accuracy: 0.0370 - val_loss: 8.2731
# Epoch 12/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 730ms/step - accuracy: 0.9964 - loss: 0.0415 - val_accuracy: 0.0370 - val_loss: 8.7291
# Epoch 13/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0199 - val_accuracy: 0.0370 - val_loss: 9.3697
# Epoch 14/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.0370 - val_loss: 10.6549
# Epoch 15/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.0370 - val_loss: 11.1845
# Epoch 16/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.0741 - val_loss: 12.0582
# Epoch 17/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.0370 - val_loss: 11.5049
# Epoch 18/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.0370 - val_loss: 11.2669
# Epoch 19/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 897ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.0741 - val_loss: 11.5179
# Epoch 20/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 744ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.0370 - val_loss: 11.6416
# Epoch 21/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 846ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.0370 - val_loss: 11.8728
# Epoch 22/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 740ms/step - accuracy: 1.0000 - loss: 9.9199e-04 - val_accuracy: 0.0370 - val_loss: 12.1400
# Epoch 23/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 948ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.0370 - val_loss: 12.3392
# Epoch 24/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 9.2592e-04 - val_accuracy: 0.0370 - val_loss: 12.7589
# Epoch 25/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 860ms/step - accuracy: 1.0000 - loss: 7.9954e-04 - val_accuracy: 0.0370 - val_loss: 12.6484

# %%
model.summary()

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history["accuracy"],label="Training Accurancy")
plt.plot(epochs_range,history.history["val_accuracy"],label="Validation Accurency")
plt.title("Accuracy")

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history["loss"],label="Training loss")
plt.plot(epochs_range,history.history["val_loss"],label="Validation loss")
plt.title("Loss")
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image ="Model/fire.jpg"
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print("Naturel disaster in image is {} with accurancy of {:0.2f}".format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Naturel disaster in image is Fire with accurancy of 100.00

# %%
model.save("Image_classify.keras")
